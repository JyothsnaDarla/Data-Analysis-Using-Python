# %%
from matplotlib import pyplot as plt

# %%
#ploting a two lists
x=[1,2,3,4,5,6,7,8]
y=[34,56,78,12,34,23,14,4]
plt.plot(x,y)#create line graph
plt.title("my frist plot")
plt.xlabel('x values')
plt.ylabel('y values')

#title,labels,legend,color,width,markers!
# Out:
# Text(0, 0.5, 'y values')

# %%
#there are 5 subjects phychology,nanotechnology,medicine,oncology,anthropology 2 students have apply to do masters in any of the 5 fields with lineplot show in which field they can excel.the cutoff for each subject is 70.now
#st1=[67,45,73,71,57]
#st2=[43,67,68,53,85]
#student1
#plt.plottype(X,y,label,color,marker,linewidth,linestYle)
x=["phychology","nanotechnology","medicine","oncology","anthropology"]
st1=[67,45,73,71,57]
st2=[43,67,68,53,85]
z=[70,70,70,70,70]
plt.scatter(x,st1,label="student-1",color="pink",marker="H")     #student1
plt.scatter(x,st2,label="student-2",color="c",marker="p")     #student 2
plt.plot(x,z,label="cutoff",color="m",linestyle=":",linewidth=2)
plt.xlabel("subjects")
plt.ylabel("marks")
plt.legend()

# %%
#an india and australia match is on live india has given 298 target as australia the runs fors every 5 overs is given as follows
#i=[25,51,84,131,160,189,220,250,267,297]
#austalia have completed 25 overs
#a=[15,41,94,110,151]#plt over vs runs for both the country with india as a blue line and austalia as a yellow line with required labels and legends the marker for india is
#flag and marker for austalia is +,take over from arange function create runs as arrays.
#plt.plottype(X,y,label,color,marker,linewidth,linestYle)


from numpy import random as rd
x=np.arange(5,51,5)
y=np.array([25,51,84,131,160,189,220,250,267,297])
a=np.array([15,41,94,110,151])
z=np.arange(5,26,5)
plt.plot(x,y,label="india",color="blue",marker=">",linewidth=3,linestyle=":")
plt.plot(z,a,label="australia",color="yellow",marker="+",linewidth=3,linestyle=":")
plt.title("india vs australia")
plt.xlabel("overs")
plt.ylabel("runs")
plt.legend()
plt.grid()

# %%
import numpy as np
from numpy import random as rd
x=np.array([5,10,15,20,25,30,35,40,45,50])
y=np.array([25,51,84,131,160,189,220,250,267,297])
a=np.array([15,41,94,110,151])
z=np.array([5,10,15,20,25])
plt.plot(x,y,label="india",color="blue",marker=">",linewidth=3,linestyle=":")
plt.plot(z,a,label="australia",color="yellow",marker="+",linewidth=3,linestyle=":")
plt.title("india vs australia")
plt.xlabel("overs")
plt.ylabel("runs")
plt.legend()
plt.grid()
