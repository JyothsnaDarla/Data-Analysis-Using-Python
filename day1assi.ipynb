# %%
#create a tuple
s=("hi","str",2,7)
print(s)
# Out:
# ('hi', 'str', 2, 7)

# %%
#access
t=(1,2,3,4,5)
print(t[1])
print(t[4])
print(t[-1])
print(t[-3])
# Out:
# 2
# 5
# 5
# 3

# %%
#concatenation
t1=(2,4,6,2,'h')
t=(3,2,1,7)
print(t1+t)
# Out:
# (2, 4, 6, 2, 'h', 3, 2, 1, 7)

# %%
#nesting
t=(0,1,2,3)
t1=('python','hi')
t2=(t1,t)
print(t2)
# Out:
# (('python', 'hi'), (0, 1, 2, 3))

# %%
t=('python',4)*3
print(t)
# Out:
# ('python', 4, 'python', 4, 'python', 4)

# %%
#slicing
t=(0,1,2,3)
print(t[1:])
print(t[::-1])
# Out:
# (1, 2, 3)
# (3, 2, 1, 0)

# %%
#delete
t=(1,2,3,4)
del t
print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0d84011f4f27> in <cell line: 4>()
#       2 t=(1,2,3,4)
#       3 del t
# ----> 4 print(t)
#
# NameError: name 't' is not defined

# %%
t=(1,2,3,4)
print(len(t))
# Out:
# 4

# %%
l=[0,1,2]
print(tuple(l))
print(tuple("jyothsna"))
# Out:
# (0, 1, 2)
# ('j', 'y', 'o', 't', 'h', 's', 'n', 'a')

# %%
t=(1,2,3,4)
print(min(t))
# Out:
# 1

# %%
t=(1,2,3,4)
print(max(t))
# Out:
# 4

# %%
#set creation
s={2,4,1,4,3,'hi'}
print(s)
# Out:
# {1, 2, 3, 'hi', 4}

# %%
#set creation
s={2,4,1,4,3,'hi'}
print(list(s))
# Out:
# [1, 2, 3, 'hi', 4]

# %%
print(set('jyo'))
# Out:
# {'j', 'y', 'o'}

# %%
s={2,4,1,4,3,'hi'}
print(len(s))
# Out:
# 5

# %%
#set creation
s={2,4,1,4,3,'hi'}
print(4 in s)
# Out:
# True

# %%
#union
x={4,5,2}
y={1,3,6}
z=x.union(y)
print(z)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#intersection
x={4,1,2}
y={1,3,6}
z=x.intersection(y)
print(z)
# Out:
# {1}

# %%
#diffe
z=x.difference(y)
print(z)
# Out:
# {2, 4}

# %%
z=x.symmetric_difference(y)
print(z)
# Out:
# {2, 3, 4, 6}

# %%
print(x.isdisjoint(y))
# Out:
# False

# %%
print(x.issubset(y))
# Out:
# False

# %%
print(x.issuperset(y))
# Out:
# False

# %%
#removing is done in 3 ways
#1.remove(element):raises error if the element is not present
#2.discard(element):dont raises error if the element is not present
#3.pop():removes random element
s3={1,2,3,"h","a","b","e"}
s3.remove(1)
s3.discard(2)
s3.pop()
print(s3)
# Out:
# {'e', 'h', 'a', 'b'}
