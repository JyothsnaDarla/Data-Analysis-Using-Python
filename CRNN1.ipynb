# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.62.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN,Dense,Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
df=pd.read_csv("/content/Earth.txt")
df
# Out:
# Empty DataFrame
# Columns: [Earth is the third planet from the Sun and the only astronomical object known to harbor life. This is enabled by Earth being a water world,  the only one in the Solar System sustaining liquid surface water. Almost all of Earth's water is contained in its global ocean,  covering 70.8% of Earth's crust. The remaining 29.2% of Earth's crust is land,  most of which is located in the form of continental landmasses within one hemisphere,  Earth's land hemisphere. Most of Earth's land is somewhat humid and covered by vegetation,  while large sheets of ice at Earth's polar deserts retain more water than Earth's groundwater,  lakes,  rivers and atmospheric water combined. Earth's crust consists of slowly moving tectonic plates,  which interact to produce mountain ranges,  volcanoes,  and earthquakes. Earth has a liquid outer core that generates a magnetosphere capable of deflecting most of the destructive solar winds and cosmic radiation.]
# Index: []

# %%
#generating some example sequential data
#sentences=['I love learning','I love python','I hate college','Recurrent neural Networks are powerfull']

# %%
#tokenizing the words
tokenizer=Tokenizer()
tokenizer.fit_on_texts(df)
total_words=len(tokenizer.word_index)+1
print(total_words)
# Out:
# 60

# %%
# Creating input sequences and their corresponding next words
input_sequences = []
for sentence in df:
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        n_gram_sequence = tokenized_sentence[:i+1]
        input_sequences.append(n_gram_sequence)
input_sequences
# Out:
# [[17, 8],
#  [17, 8, 4],
#  [17, 8, 4, 18],
#  [17, 8, 4, 18, 5],
#  [19, 20],
#  [19, 20, 21],
#  [19, 20, 21, 9],
#  [19, 20, 21, 9, 10],
#  [19, 20, 21, 9, 10, 2],
#  [19, 20, 21, 9, 10, 2, 22],
#  [19, 20, 21, 9, 10, 2, 22, 11],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25, 26],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25, 26, 11],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25, 26, 11, 8],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25, 26, 11, 8, 4],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25, 26, 11, 8, 4, 27],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5],
#  [34, 35],
#  [34, 35, 36],
#  [34, 35, 36, 37],
#  [34, 35, 36, 37, 13],
#  [34, 35, 36, 37, 13, 6],
#  [34, 35, 36, 37, 13, 6, 1],
#  [34, 35, 36, 37, 13, 6, 1, 38],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39, 40],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39, 40, 4],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39, 40, 4, 16],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39, 40, 4, 16, 41],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39, 40, 4, 16, 41, 2],
#  [42, 43],
#  [42, 43, 44],
#  [42, 43, 44, 16],
#  [42, 43, 44, 16, 45],
#  [42, 43, 44, 16, 45, 15],
#  [42, 43, 44, 16, 45, 15, 1],
#  [42, 43, 44, 16, 45, 15, 1, 5],
#  [46, 47],
#  [46, 47, 48],
#  [46, 47, 48, 49],
#  [50, 1],
#  [50, 1, 10],
#  [50, 1, 10, 51],
#  [50, 1, 10, 51, 52],
#  [50, 1, 10, 51, 52, 53],
#  [50, 1, 10, 51, 52, 53, 9],
#  [50, 1, 10, 51, 52, 53, 9, 3],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57, 6],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57, 6, 58],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57, 6, 58, 12],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57, 6, 58, 12, 1],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57, 6, 58, 12, 1, 59],
#  [50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58,
#   12,
#   1,
#   59,
#   14]]

# %%
# Padding sequences for consistent input size
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# %%
input_sequences
# Out:
# array([[ 0,  0,  0,  1,  2],
#        [ 0,  0,  1,  2,  3],
#        [ 0,  0,  0,  1,  2],
#        [ 0,  0,  1,  2,  4],
#        [ 0,  0,  0,  1,  5],
#        [ 0,  0,  1,  5,  6],
#        [ 0,  0,  0,  7,  8],
#        [ 0,  0,  7,  8,  9],
#        [ 0,  7,  8,  9, 10],
#        [ 7,  8,  9, 10, 11]], dtype=int32)

# %%
# Creating input and output data
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
# Building a simple RNN model
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# %%
#compile the model
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
#trainig the model
model.fit(X,y,epochs=50,verbose=2)
# Out:
# Epoch 1/50
# 3/3 - 2s - loss: 4.1346 - accuracy: 0.0361 - 2s/epoch - 701ms/step
# Epoch 2/50
# 3/3 - 0s - loss: 3.8661 - accuracy: 0.0964 - 51ms/epoch - 17ms/step
# Epoch 3/50
# 3/3 - 0s - loss: 3.7084 - accuracy: 0.1205 - 68ms/epoch - 23ms/step
# Epoch 4/50
# 3/3 - 0s - loss: 3.5563 - accuracy: 0.1928 - 51ms/epoch - 17ms/step
# Epoch 5/50
# 3/3 - 0s - loss: 3.4354 - accuracy: 0.2289 - 54ms/epoch - 18ms/step
# Epoch 6/50
# 3/3 - 0s - loss: 3.3076 - accuracy: 0.2651 - 57ms/epoch - 19ms/step
# Epoch 7/50
# 3/3 - 0s - loss: 3.1625 - accuracy: 0.3253 - 53ms/epoch - 18ms/step
# Epoch 8/50
# 3/3 - 0s - loss: 3.0283 - accuracy: 0.4217 - 52ms/epoch - 17ms/step
# Epoch 9/50
# 3/3 - 0s - loss: 2.9013 - accuracy: 0.4217 - 52ms/epoch - 17ms/step
# Epoch 10/50
# 3/3 - 0s - loss: 2.7573 - accuracy: 0.5422 - 51ms/epoch - 17ms/step
# Epoch 11/50
# 3/3 - 0s - loss: 2.6416 - accuracy: 0.6386 - 51ms/epoch - 17ms/step
# Epoch 12/50
# 3/3 - 0s - loss: 2.5227 - accuracy: 0.6386 - 58ms/epoch - 19ms/step
# Epoch 13/50
# 3/3 - 0s - loss: 2.3933 - accuracy: 0.6386 - 52ms/epoch - 17ms/step
# Epoch 14/50
# 3/3 - 0s - loss: 2.2964 - accuracy: 0.6145 - 54ms/epoch - 18ms/step
# Epoch 15/50
# 3/3 - 0s - loss: 2.1877 - accuracy: 0.6145 - 59ms/epoch - 20ms/step
# Epoch 16/50
# 3/3 - 0s - loss: 2.0583 - accuracy: 0.6867 - 57ms/epoch - 19ms/step
# Epoch 17/50
# 3/3 - 0s - loss: 1.9608 - accuracy: 0.7108 - 53ms/epoch - 18ms/step
# Epoch 18/50
# 3/3 - 0s - loss: 1.8714 - accuracy: 0.6747 - 52ms/epoch - 17ms/step
# Epoch 19/50
# 3/3 - 0s - loss: 1.7746 - accuracy: 0.6627 - 59ms/epoch - 20ms/step
# Epoch 20/50
# 3/3 - 0s - loss: 1.6848 - accuracy: 0.7229 - 63ms/epoch - 21ms/step
# Epoch 21/50
# 3/3 - 0s - loss: 1.6044 - accuracy: 0.7711 - 51ms/epoch - 17ms/step
# Epoch 22/50
# 3/3 - 0s - loss: 1.5185 - accuracy: 0.8072 - 50ms/epoch - 17ms/step
# Epoch 23/50
# 3/3 - 0s - loss: 1.4420 - accuracy: 0.7952 - 55ms/epoch - 18ms/step
# Epoch 24/50
# 3/3 - 0s - loss: 1.3743 - accuracy: 0.7952 - 50ms/epoch - 17ms/step
# Epoch 25/50
# 3/3 - 0s - loss: 1.3059 - accuracy: 0.7831 - 52ms/epoch - 17ms/step
# Epoch 26/50
# 3/3 - 0s - loss: 1.2461 - accuracy: 0.8313 - 53ms/epoch - 18ms/step
# Epoch 27/50
# 3/3 - 0s - loss: 1.1803 - accuracy: 0.8554 - 57ms/epoch - 19ms/step
# Epoch 28/50
# 3/3 - 0s - loss: 1.1184 - accuracy: 0.8193 - 52ms/epoch - 17ms/step
# Epoch 29/50
# 3/3 - 0s - loss: 1.0661 - accuracy: 0.8434 - 53ms/epoch - 18ms/step
# Epoch 30/50
# 3/3 - 0s - loss: 1.0174 - accuracy: 0.8554 - 51ms/epoch - 17ms/step
# Epoch 31/50
# 3/3 - 0s - loss: 0.9689 - accuracy: 0.8795 - 57ms/epoch - 19ms/step
# Epoch 32/50
# 3/3 - 0s - loss: 0.9269 - accuracy: 0.8916 - 51ms/epoch - 17ms/step
# Epoch 33/50
# 3/3 - 0s - loss: 0.8816 - accuracy: 0.9277 - 54ms/epoch - 18ms/step
# Epoch 34/50
# 3/3 - 0s - loss: 0.8624 - accuracy: 0.9157 - 50ms/epoch - 17ms/step
# Epoch 35/50
# 3/3 - 0s - loss: 0.8116 - accuracy: 0.9157 - 51ms/epoch - 17ms/step
# Epoch 36/50
# 3/3 - 0s - loss: 0.7695 - accuracy: 0.8916 - 53ms/epoch - 18ms/step
# Epoch 37/50
# 3/3 - 0s - loss: 0.7436 - accuracy: 0.9277 - 56ms/epoch - 19ms/step
# Epoch 38/50
# 3/3 - 0s - loss: 0.7057 - accuracy: 0.9157 - 63ms/epoch - 21ms/step
# Epoch 39/50
# 3/3 - 0s - loss: 0.6760 - accuracy: 0.9036 - 50ms/epoch - 17ms/step
# Epoch 40/50
# 3/3 - 0s - loss: 0.6403 - accuracy: 0.9398 - 49ms/epoch - 16ms/step
# Epoch 41/50
# 3/3 - 0s - loss: 0.6026 - accuracy: 0.9518 - 53ms/epoch - 18ms/step
# Epoch 42/50
# 3/3 - 0s - loss: 0.6080 - accuracy: 0.9157 - 53ms/epoch - 18ms/step
# Epoch 43/50
# 3/3 - 0s - loss: 0.5633 - accuracy: 0.9880 - 52ms/epoch - 17ms/step
# Epoch 44/50
# 3/3 - 0s - loss: 0.5371 - accuracy: 0.9518 - 56ms/epoch - 19ms/step
# Epoch 45/50
# 3/3 - 0s - loss: 0.5093 - accuracy: 0.9639 - 53ms/epoch - 18ms/step
# Epoch 46/50
# 3/3 - 0s - loss: 0.4783 - accuracy: 0.9639 - 52ms/epoch - 17ms/step
# Epoch 47/50
# 3/3 - 0s - loss: 0.4566 - accuracy: 0.9759 - 56ms/epoch - 19ms/step
# Epoch 48/50
# 3/3 - 0s - loss: 0.4379 - accuracy: 0.9639 - 59ms/epoch - 20ms/step
# Epoch 49/50
# 3/3 - 0s - loss: 0.4089 - accuracy: 0.9759 - 53ms/epoch - 18ms/step
# Epoch 50/50
# 3/3 - 0s - loss: 0.4066 - accuracy: 0.9398 - 51ms/epoch - 17ms/step

# %%
#test
# Generating text using the trained model
seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))

for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word

print(seed_text)
# Out:
# Enter the starting word: I
# Enter how many words to predict: 2
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# I love python

# %%
import pandas as pd

# %%
df2=pd.read_csv("/content/earthe.txt")
df2
# Out:
# Empty DataFrame
# Columns: [Earth has a dynamic atmosphere,  which sustains Earth's surface conditions and protects it from most meteoroids and UV-light at entry. It has a composition of primarily nitrogen and oxygen. Water vapor is widely present in the atmosphere,  forming clouds that cover most of the planet. The water vapor acts as a greenhouse gas and,  together with other greenhouse gases in the atmosphere,  particularly carbon dioxide (CO2),  creates the conditions for both liquid surface water and water vapor to persist via the capturing of energy from the Sun's light. ]
# Index: []

# %%
#tokenizing the words
tokenizer=Tokenizer()
tokenizer.fit_on_texts(df2)
total_words=len(tokenizer.word_index)+1
print(total_words)
# Out:
# 60

# %%
input_sequences = []
for sentence in df2:
  tokenized_sentence=tokenizer.texts_to_sequences([sentence])[0]
  for i in range(1, len(tokenized_sentence)):
      n_gram_sequence = tokenized_sentence[:i+1]
      input_sequences.append(n_gram_sequence)
input_sequences
# Out:
# [[17, 8],
#  [17, 8, 4],
#  [17, 8, 4, 18],
#  [17, 8, 4, 18, 5],
#  [19, 20],
#  [19, 20, 21],
#  [19, 20, 21, 9],
#  [19, 20, 21, 9, 10],
#  [19, 20, 21, 9, 10, 2],
#  [19, 20, 21, 9, 10, 2, 22],
#  [19, 20, 21, 9, 10, 2, 22, 11],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25, 26],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25, 26, 11],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25, 26, 11, 8],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25, 26, 11, 8, 4],
#  [19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25, 26, 11, 8, 4, 27],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1],
#  [19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26,
#   11,
#   8,
#   4,
#   27,
#   6,
#   28,
#   29,
#   2,
#   30,
#   3,
#   7,
#   31,
#   32,
#   33,
#   15,
#   1,
#   5],
#  [34, 35],
#  [34, 35, 36],
#  [34, 35, 36, 37],
#  [34, 35, 36, 37, 13],
#  [34, 35, 36, 37, 13, 6],
#  [34, 35, 36, 37, 13, 6, 1],
#  [34, 35, 36, 37, 13, 6, 1, 38],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39, 40],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39, 40, 4],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39, 40, 4, 16],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39, 40, 4, 16, 41],
#  [34, 35, 36, 37, 13, 6, 1, 38, 1, 3, 7, 39, 40, 4, 16, 41, 2],
#  [42, 43],
#  [42, 43, 44],
#  [42, 43, 44, 16],
#  [42, 43, 44, 16, 45],
#  [42, 43, 44, 16, 45, 15],
#  [42, 43, 44, 16, 45, 15, 1],
#  [42, 43, 44, 16, 45, 15, 1, 5],
#  [46, 47],
#  [46, 47, 48],
#  [46, 47, 48, 49],
#  [50, 1],
#  [50, 1, 10],
#  [50, 1, 10, 51],
#  [50, 1, 10, 51, 52],
#  [50, 1, 10, 51, 52, 53],
#  [50, 1, 10, 51, 52, 53, 9],
#  [50, 1, 10, 51, 52, 53, 9, 3],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57, 6],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57, 6, 58],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57, 6, 58, 12],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57, 6, 58, 12, 1],
#  [50, 1, 10, 51, 52, 53, 9, 3, 2, 3, 7, 54, 55, 56, 1, 57, 6, 58, 12, 1, 59],
#  [50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58,
#   12,
#   1,
#   59,
#   14]]

# %%
# Padding sequences for consistent input size
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# %%
input_sequences
# Out:
# array([[ 0,  0,  0, ...,  0, 17,  8],
#        [ 0,  0,  0, ..., 17,  8,  4],
#        [ 0,  0,  0, ...,  8,  4, 18],
#        ...,
#        [ 0,  0,  0, ..., 58, 12,  1],
#        [ 0,  0,  0, ..., 12,  1, 59],
#        [ 0,  0,  0, ...,  1, 59, 14]], dtype=int32)

# %%
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X,y,epochs=50,verbose=2)
# Out:
# Epoch 1/50
# 3/3 - 2s - loss: 4.1101 - accuracy: 0.0241 - 2s/epoch - 699ms/step
# Epoch 2/50
# 3/3 - 0s - loss: 3.9345 - accuracy: 0.0964 - 50ms/epoch - 17ms/step
# Epoch 3/50
# 3/3 - 0s - loss: 3.7606 - accuracy: 0.1566 - 49ms/epoch - 16ms/step
# Epoch 4/50
# 3/3 - 0s - loss: 3.6333 - accuracy: 0.1807 - 49ms/epoch - 16ms/step
# Epoch 5/50
# 3/3 - 0s - loss: 3.5076 - accuracy: 0.1807 - 50ms/epoch - 17ms/step
# Epoch 6/50
# 3/3 - 0s - loss: 3.3936 - accuracy: 0.2771 - 50ms/epoch - 17ms/step
# Epoch 7/50
# 3/3 - 0s - loss: 3.2435 - accuracy: 0.3133 - 54ms/epoch - 18ms/step
# Epoch 8/50
# 3/3 - 0s - loss: 3.1066 - accuracy: 0.3735 - 52ms/epoch - 17ms/step
# Epoch 9/50
# 3/3 - 0s - loss: 2.9741 - accuracy: 0.4217 - 54ms/epoch - 18ms/step
# Epoch 10/50
# 3/3 - 0s - loss: 2.8314 - accuracy: 0.4699 - 52ms/epoch - 17ms/step
# Epoch 11/50
# 3/3 - 0s - loss: 2.6949 - accuracy: 0.5422 - 53ms/epoch - 18ms/step
# Epoch 12/50
# 3/3 - 0s - loss: 2.5728 - accuracy: 0.5663 - 55ms/epoch - 18ms/step
# Epoch 13/50
# 3/3 - 0s - loss: 2.4395 - accuracy: 0.5904 - 57ms/epoch - 19ms/step
# Epoch 14/50
# 3/3 - 0s - loss: 2.3291 - accuracy: 0.6386 - 52ms/epoch - 17ms/step
# Epoch 15/50
# 3/3 - 0s - loss: 2.2014 - accuracy: 0.6747 - 50ms/epoch - 17ms/step
# Epoch 16/50
# 3/3 - 0s - loss: 2.0835 - accuracy: 0.6145 - 50ms/epoch - 17ms/step
# Epoch 17/50
# 3/3 - 0s - loss: 1.9753 - accuracy: 0.7108 - 52ms/epoch - 17ms/step
# Epoch 18/50
# 3/3 - 0s - loss: 1.8758 - accuracy: 0.7470 - 65ms/epoch - 22ms/step
# Epoch 19/50
# 3/3 - 0s - loss: 1.7759 - accuracy: 0.7229 - 55ms/epoch - 18ms/step
# Epoch 20/50
# 3/3 - 0s - loss: 1.6760 - accuracy: 0.7349 - 54ms/epoch - 18ms/step
# Epoch 21/50
# 3/3 - 0s - loss: 1.5882 - accuracy: 0.7590 - 58ms/epoch - 19ms/step
# Epoch 22/50
# 3/3 - 0s - loss: 1.5089 - accuracy: 0.7952 - 57ms/epoch - 19ms/step
# Epoch 23/50
# 3/3 - 0s - loss: 1.4298 - accuracy: 0.7711 - 61ms/epoch - 20ms/step
# Epoch 24/50
# 3/3 - 0s - loss: 1.3540 - accuracy: 0.7590 - 58ms/epoch - 19ms/step
# Epoch 25/50
# 3/3 - 0s - loss: 1.2974 - accuracy: 0.8554 - 58ms/epoch - 19ms/step
# Epoch 26/50
# 3/3 - 0s - loss: 1.2286 - accuracy: 0.7831 - 58ms/epoch - 19ms/step
# Epoch 27/50
# 3/3 - 0s - loss: 1.1764 - accuracy: 0.8795 - 55ms/epoch - 18ms/step
# Epoch 28/50
# 3/3 - 0s - loss: 1.1170 - accuracy: 0.8554 - 54ms/epoch - 18ms/step
# Epoch 29/50
# 3/3 - 0s - loss: 1.0478 - accuracy: 0.8675 - 52ms/epoch - 17ms/step
# Epoch 30/50
# 3/3 - 0s - loss: 1.0018 - accuracy: 0.8916 - 54ms/epoch - 18ms/step
# Epoch 31/50
# 3/3 - 0s - loss: 0.9562 - accuracy: 0.8554 - 52ms/epoch - 17ms/step
# Epoch 32/50
# 3/3 - 0s - loss: 0.9159 - accuracy: 0.9036 - 50ms/epoch - 17ms/step
# Epoch 33/50
# 3/3 - 0s - loss: 0.8677 - accuracy: 0.9036 - 50ms/epoch - 17ms/step
# Epoch 34/50
# 3/3 - 0s - loss: 0.8231 - accuracy: 0.9157 - 55ms/epoch - 18ms/step
# Epoch 35/50
# 3/3 - 0s - loss: 0.7850 - accuracy: 0.9036 - 84ms/epoch - 28ms/step
# Epoch 36/50
# 3/3 - 0s - loss: 0.7506 - accuracy: 0.9157 - 82ms/epoch - 27ms/step
# Epoch 37/50
# 3/3 - 0s - loss: 0.7104 - accuracy: 0.9277 - 87ms/epoch - 29ms/step
# Epoch 38/50
# 3/3 - 0s - loss: 0.6869 - accuracy: 0.9157 - 98ms/epoch - 33ms/step
# Epoch 39/50
# 3/3 - 0s - loss: 0.6527 - accuracy: 0.9518 - 84ms/epoch - 28ms/step
# Epoch 40/50
# 3/3 - 0s - loss: 0.6233 - accuracy: 0.9518 - 86ms/epoch - 29ms/step
# Epoch 41/50
# 3/3 - 0s - loss: 0.5857 - accuracy: 0.9518 - 97ms/epoch - 32ms/step
# Epoch 42/50
# 3/3 - 0s - loss: 0.5651 - accuracy: 0.9518 - 102ms/epoch - 34ms/step
# Epoch 43/50
# 3/3 - 0s - loss: 0.5354 - accuracy: 0.9639 - 101ms/epoch - 34ms/step
# Epoch 44/50
# 3/3 - 0s - loss: 0.5118 - accuracy: 0.9518 - 108ms/epoch - 36ms/step
# Epoch 45/50
# 3/3 - 0s - loss: 0.4887 - accuracy: 0.9759 - 108ms/epoch - 36ms/step
# Epoch 46/50
# 3/3 - 0s - loss: 0.4681 - accuracy: 0.9639 - 103ms/epoch - 34ms/step
# Epoch 47/50
# 3/3 - 0s - loss: 0.4444 - accuracy: 0.9518 - 94ms/epoch - 31ms/step
# Epoch 48/50
# 3/3 - 0s - loss: 0.4356 - accuracy: 0.9398 - 90ms/epoch - 30ms/step
# Epoch 49/50
# 3/3 - 0s - loss: 0.4154 - accuracy: 0.9518 - 92ms/epoch - 31ms/step
# Epoch 50/50
# 3/3 - 0s - loss: 0.4012 - accuracy: 0.9639 - 92ms/epoch - 31ms/step

# %%
seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))

for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word

print(seed_text)
# Out:
# Enter the starting word: earth
# Enter how many words to predict: 4
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# earth has a dynamic atmosphere
